# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os

# %%
class CartPoleTrainer:
    def __init__(self, is_training=True, render=False, learning_rate=0.1, discount_factor=0.99, epsilon=1, decay=0.01):
        self.is_training = is_training
        self.render = render
        self.env = gym.make('CartPole-v1', render_mode='human' if self.render else None)

        #Only have a limited amount of possible values
        self.pos_space = np.linspace(-2.4, 2.4, 10)
        self.vel_space = np.linspace(-4, 4, 10)
        self.ang_space = np.linspace(-.2095, .2095, 10)
        self.ang_vel_space = np.linspace(-4, 4, 10)

        self.q = self._initialize_q()
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.epsilon_decay_rate = decay
        self.rng = np.random.default_rng()

    def _initialize_q(self):
        if self.is_training:
            return np.zeros((len(self.pos_space)+1, len(self.vel_space)+1, len(self.ang_space)+1, len(self.ang_vel_space)+1, self.env.action_space.n))
        else:
            if not os.path.getsize('cartpole.pkl') > 0:
                raise ValueError("The 'cartpole.pkl' file is empty. Please run the code with is_training=True first.")
            with open('cartpole.pkl', 'rb') as f:
                return pickle.load(f)

    def run(self):
        rewards_per_episode = []
        i = 0

        while True:
            state = self.env.reset()[0]
            state_p, state_v, state_a, state_av = self._digitize_state(state)

            terminated = False
            rewards = 0

            while not terminated and rewards < 10000:
                action = self._choose_action(state_p, state_v, state_a, state_av)
                new_state, reward, terminated, _, _ = self.env.step(action)
                new_state_p, new_state_v, new_state_a, new_state_av = self._digitize_state(new_state)

                if self.is_training:
                    self._update_q(state_p, state_v, state_a, state_av, action, reward, new_state_p, new_state_v, new_state_a, new_state_av)

                state = new_state
                state_p, state_v, state_a, state_av = new_state_p, new_state_v, new_state_a, new_state_av
                rewards += reward

                if not self.is_training and rewards % 100 == 0:
                    print(f'Episode: {i}  Rewards: {rewards}')

            rewards_per_episode.append(rewards)
            self._print_training_stats(i, rewards, rewards_per_episode)

            if np.mean(rewards_per_episode[-100:]) > 1000:
                break

            self.epsilon = max(self.epsilon - self.epsilon_decay_rate, 0)
            i += 1

        self.env.close()
        self._save_results(rewards_per_episode, i)

    def _digitize_state(self, state):
        state_p = np.digitize(state[0], self.pos_space)
        state_v = np.digitize(state[1], self.vel_space)
        state_a = np.digitize(state[2], self.ang_space)
        state_av = np.digitize(state[3], self.ang_vel_space)
        return state_p, state_v, state_a, state_av

    def _choose_action(self, state_p, state_v, state_a, state_av):
        if self.is_training and self.rng.random() < self.epsilon:
            return self.env.action_space.sample()
        else:
            return np.argmax(self.q[state_p, state_v, state_a, state_av, :])

    def _update_q(self, state_p, state_v, state_a, state_av, action, reward, new_state_p, new_state_v, new_state_a, new_state_av):
        self.q[state_p, state_v, state_a, state_av, action] += self.learning_rate * (
            reward + self.discount_factor * np.max(self.q[new_state_p, new_state_v, new_state_a, new_state_av, :]) - self.q[state_p, state_v, state_a, state_av, action]
        )

    def _print_training_stats(self, i, rewards, rewards_per_episode):
        if self.is_training and i % 100 == 0:
            print(f'Episode: {i} {rewards}  Epsilon: {self.epsilon:.2f}  Mean Rewards {np.mean(rewards_per_episode[-100:]):.1f}')

    def _save_results(self, rewards_per_episode, i):
        if self.is_training:
            with open('cartpole.pkl', 'wb') as f:
                pickle.dump(self.q, f)

        mean_rewards = [np.mean(rewards_per_episode[max(0, t-100):(t+1)]) for t in range(i)]
        plt.plot(mean_rewards)
        plt.savefig('cartpole.png')

if __name__ == '__main__':
    trainer = CartPoleTrainer(is_training=True, render=True)
    trainer.run()
# Out:
# Episode: 0 26.0  Epsilon: 1.00  Mean Rewards 26.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\chris\Desktop\NTNU Ting\5. Semester\MachineLearning\Øvninger\Øvning 8\QLearn-cartpole2.ipynb Cell 2 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/NTNU%20Ting/5.%20Semester/MachineLearning/%C3%98vninger/%C3%98vning%208/QLearn-cartpole2.ipynb#W0sZmlsZQ%3D%3D?line=96'>97</a> if __name__ == '__main__':
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/NTNU%20Ting/5.%20Semester/MachineLearning/%C3%98vninger/%C3%98vning%208/QLearn-cartpole2.ipynb#W0sZmlsZQ%3D%3D?line=97'>98</a>     trainer = CartPoleTrainer(is_training=True, render=True)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/NTNU%20Ting/5.%20Semester/MachineLearning/%C3%98vninger/%C3%98vning%208/QLearn-cartpole2.ipynb#W0sZmlsZQ%3D%3D?line=98'>99</a>     trainer.run()
#
# c:\Users\chris\Desktop\NTNU Ting\5. Semester\MachineLearning\Øvninger\Øvning 8\QLearn-cartpole2.ipynb Cell 2 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/NTNU%20Ting/5.%20Semester/MachineLearning/%C3%98vninger/%C3%98vning%208/QLearn-cartpole2.ipynb#W0sZmlsZQ%3D%3D?line=38'>39</a> while not terminated and rewards < 10000:
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/NTNU%20Ting/5.%20Semester/MachineLearning/%C3%98vninger/%C3%98vning%208/QLearn-cartpole2.ipynb#W0sZmlsZQ%3D%3D?line=39'>40</a>     action = self._choose_action(state_p, state_v, state_a, state_av)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/NTNU%20Ting/5.%20Semester/MachineLearning/%C3%98vninger/%C3%98vning%208/QLearn-cartpole2.ipynb#W0sZmlsZQ%3D%3D?line=40'>41</a>     new_state, reward, terminated, _, _ = self.env.step(action)
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/NTNU%20Ting/5.%20Semester/MachineLearning/%C3%98vninger/%C3%98vning%208/QLearn-cartpole2.ipynb#W0sZmlsZQ%3D%3D?line=41'>42</a>     new_state_p, new_state_v, new_state_a, new_state_av = self._digitize_state(new_state)
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Desktop/NTNU%20Ting/5.%20Semester/MachineLearning/%C3%98vninger/%C3%98vning%208/QLearn-cartpole2.ipynb#W0sZmlsZQ%3D%3D?line=43'>44</a>     if self.is_training:
#
# File c:\Users\chris\Desktop\NTNU Ting\5. Semester\MachineLearning\Øvninger\MLenviroment\lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\chris\Desktop\NTNU Ting\5. Semester\MachineLearning\Øvninger\MLenviroment\lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File c:\Users\chris\Desktop\NTNU Ting\5. Semester\MachineLearning\Øvninger\MLenviroment\lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File c:\Users\chris\Desktop\NTNU Ting\5. Semester\MachineLearning\Øvninger\MLenviroment\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:190, in CartPoleEnv.step(self, action)
#     187     reward = 0.0
#     189 if self.render_mode == "human":
# --> 190     self.render()
#     191 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File c:\Users\chris\Desktop\NTNU Ting\5. Semester\MachineLearning\Øvninger\MLenviroment\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
